# %% [markdown]
# In this assignment I chose to perform my supervised learning to predict the NBA All Stars for the 2019-2020 season. All data was pulled from `https://www.basketball-reference.com/`. I used the season data from the 2016-2017, 2017-2018, and 2018-2019 seasons along with the chosen all star team members from those respective seasons.
#
# I chose 2 types of supervised classifier models (knn and random forest) to perform the classifications. Both performed with high accuracy, but had a hard time classifying the all stars with a high accuracy, given that the dataset was so imbalanced (far more non all stars than all stars).
#
# In the test sets, the notable differences between actual and predicted all stars included:
#
# Actual but not Predicted (model says they shouldn't have been all stars)
# - Giannis Antetokounmpo, 2016
# - Kyle Lowry, 2018
# - Klay Thompson, 2016
# - LaMarcus Aldridge, 2017
# - Dirk Nowitzki, 2018
# - Khris Middleton, 2018
# - DeAndre Jordan, 2016
#
# Predicted but not Actual (model says they should've been all stars, but were not)
# - Marc Gasol, 2017
# - CJ McCollum, 2016
#
# Also, using the dataset from the 2019-2020 season so far, the projected all stars include
# - Pascal Siakam
# - LeBron James
# - Kawhi Leonard
# - Bradley Beal
# - Buddy Hield
# - Paul George
# - Karl-Anthony Towns
# - Donovan Mitchell
# - Brandon Ingram
# - Kyrie Irving
# - Andrew Wiggins
# - Anthony Davis
# - Damian Lillard
# - CJ McCollum
# - Giannis Antetokounmpo
# - James Harden
# - DeMar DeRozan

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import scale
from sklearn import metrics
from matplotlib import pyplot as plt

pd.set_option('display.max_columns', 999)

# %% [markdown]
# ### Data Preparation

# %%
team_dict = {'Atlanta Hawks': 'ATL', 'Boston Celtics': 'BOS', 'Brooklyn Nets': 'BRK', 
             'Charlotte Hornets': 'CHO', 'Chicago Bulls': 'CHI', 'Cleveland Cavaliers': 'CLE', 
             'Dallas Mavericks': 'DAL', 'Denver Nuggets': 'DEN', 
             'Detroit Pistons': 'DET', 'Golden State Warriors': 'GSW', 
             'Houston Rockets': 'HOU', 'Indiana Pacers': 'IND', 'Los Angeles Clippers': 'LAC', 
             'Los Angeles Lakers': 'LAL', 'Memphis Grizzlies': 'MEM', 'Miami Heat': 'MIA', 
             'Milwaukee Bucks': 'MIL', 'Minnesota Timberwolves': 'MIN', 'New Orleans Pelicans': 'NOP', 
             'New York Knicks': 'NYK', 'Oklahoma City Thunder': 'OKC', 'Orlando Magic': 'ORL', 
             'Philadelphia 76ers': 'PHI', 'Phoenix Suns': 'PHO', 'Portland Trail Blazers': 'POR', 
             'Sacramento Kings': 'SAC', 'San Antonio Spurs': 'SAS', 'Toronto Raptors': 'TOR', 
             'Utah Jazz': 'UTA', 'Washington Wizards': 'WAS'}

# %%
w_2016 = pd.read_csv('data/2016_wins.csv')
w_2016['win%'] = w_2016.Overall.apply(lambda x: float(x.split('-')[0])/(float(x.split('-')[0])+float(x.split('-')[1])))
w2016 = w_2016[['Team','Overall','win%']]
w2016['Tm'] = w2016.Team.apply(lambda x: team_dict[x])
w2016.head()
# Out:
# /Users/samfangman/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#                     Team Overall      win%   Tm
# 0  Golden State Warriors   67-15  0.817073  GSW
# 1      San Antonio Spurs   61-21  0.743902  SAS
# 2        Houston Rockets   55-27  0.670732  HOU
# 3         Boston Celtics   53-29  0.646341  BOS
# 4    Cleveland Cavaliers   51-31  0.621951  CLE

# %%
as2016 = pd.read_csv('data/AS_2016.csv')
as2016['year'] = 2016
as2016['name'] = as2016['Starters'].apply(lambda x: x.split("\\")[0])
as_2016 = as2016['name'].tolist()

w_2016 = pd.read_csv('data/2016_wins.csv')
w_2016['win%'] = w_2016.Overall.apply(lambda x: float(x.split('-')[0])/(float(x.split('-')[0])+float(x.split('-')[1])))
w2016 = w_2016[['Team','Overall','win%']]
w2016['Tm'] = w2016.Team.apply(lambda x: team_dict[x])

d2016 = pd.read_csv('data/2016.csv')
d2016['year'] = 2016
d2016['name'] = d2016['Player'].apply(lambda x: x.split("\\")[0])
d2016['allstar'] = d2016['name'].apply(lambda x: 1 if x in as_2016 else 0)
mt2016 = d2016[d2016['Tm']=='TOT']['name'].tolist()
d2016.drop(d2016[(d2016['name'].isin(mt2016)) & (d2016['Tm']!='TOT')].index , inplace=True)
d2016 = d2016.merge(w2016, on='Tm')


as2017 = pd.read_csv('data/AS_2017.csv')
as2017['year'] = 2017
as2017['name'] = as2017['Starters'].apply(lambda x: x.split("\\")[0])
as_2017 = as2017['name'].tolist()

w_2017 = pd.read_csv('data/2017_wins.csv')
w_2017['win%'] = w_2017.Overall.apply(lambda x: float(x.split('-')[0])/(float(x.split('-')[0])+float(x.split('-')[1])))
w2017 = w_2017[['Team','Overall','win%']]
w2017['Tm'] = w2017.Team.apply(lambda x: team_dict[x])

d2017 = pd.read_csv('data/2017.csv')
d2017['year'] = 2017
d2017['name'] = d2017['Player'].apply(lambda x: x.split("\\")[0])
d2017['allstar'] = d2017['name'].apply(lambda x: 1 if x in as_2017 else 0)
mt2017 = d2017[d2017['Tm']=='TOT']['name'].tolist()
d2017.drop(d2017[(d2017['name'].isin(mt2017)) & (d2017['Tm']!='TOT')].index , inplace=True)
d2017 = d2017.merge(w2017, on='Tm')

as2018 = pd.read_csv('data/AS_2018.csv')
as2018['year'] = 2018
as2018['name'] = as2018['Starters'].apply(lambda x: x.split("\\")[0])
as_2018 = as2018['name'].tolist()

w_2018 = pd.read_csv('data/2018_wins.csv')
w_2018['win%'] = w_2018.Overall.apply(lambda x: float(x.split('-')[0])/(float(x.split('-')[0])+float(x.split('-')[1])))
w2018 = w_2018[['Team','Overall','win%']]
w2018['Tm'] = w2018.Team.apply(lambda x: team_dict[x])

d2018 = pd.read_csv('data/2018.csv')
d2018['year'] = 2018
d2018['name'] = d2018['Player'].apply(lambda x: x.split("\\")[0])
d2018['allstar'] = d2018['name'].apply(lambda x: 1 if x in as_2018 else 0)
mt2018 = d2018[d2018['Tm']=='TOT']['name'].tolist()
d2018.drop(d2018[(d2018['name'].isin(mt2018)) & (d2018['Tm']!='TOT')].index , inplace=True)
d2018 = d2018.merge(w2018, on='Tm')

w_2019 = pd.read_csv('data/2019_wins.csv')
w_2019['win%'] = w_2019.Overall.apply(lambda x: float(x.split('-')[0])/(float(x.split('-')[0])+float(x.split('-')[1])))
w2019 = w_2019[['Team','Overall','win%']]
w2019['Tm'] = w2019.Team.apply(lambda x: team_dict[x])

d2019 = pd.read_csv('data/2019.csv')
d2019['year'] = 2019
d2019['name'] = d2019['Player'].apply(lambda x: x.split("\\")[0])
d2019.fillna(0, inplace=True)
d2019['GS%'] = d2019['GS']/d2019['G']
d2019 = d2019.merge(w2019, on='Tm')


df = pd.concat([d2016, d2017, d2018])
df['GS%'] = df['GS']/df['G']
# df['GP_percentile']
df.fillna(0, inplace=True)

df.head()
# Out:
# /Users/samfangman/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /Users/samfangman/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/samfangman/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/samfangman/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    Rk                    Player Pos  Age   Tm   G  GS    MP   FG  FGA    FG%  \
# 0   1    Álex Abrines\abrinal01  SG   23  OKC  68   6  15.5  2.0  5.0  0.393
# 1   3    Steven Adams\adamsst01   C   23  OKC  80  80  29.9  4.7  8.2  0.571
# 2  81  Semaj Christon\chrisse01  PG   24  OKC  64   1  15.2  1.2  3.5  0.345
# 3  84      Norris Cole\coleno01  PG   28  OKC  13   0   9.6  1.2  4.0  0.308
# 4  86   Nick Collison\collini01  PF   36  OKC  20   0   6.4  0.7  1.2  0.609
#
#     3P  3PA    3P%   2P  2PA    2P%   eFG%   FT  FTA    FT%  ORB  DRB  TRB  \
# 0  1.4  3.6  0.381  0.6  1.4  0.426  0.531  0.6  0.7  0.898  0.3  1.0  1.3
# 1  0.0  0.0  0.000  4.7  8.2  0.572  0.571  2.0  3.2  0.611  3.5  4.2  7.7
# 2  0.2  1.0  0.190  1.0  2.5  0.406  0.372  0.3  0.5  0.548  0.3  1.1  1.4
# 3  0.2  1.0  0.231  1.0  3.0  0.333  0.337  0.6  0.8  0.800  0.0  0.8  0.8
# 4  0.0  0.1  0.000  0.7  1.1  0.636  0.609  0.3  0.4  0.625  0.5  1.1  1.6
#
#    AST  STL  BLK  TOV   PF   PTS  year            name  allstar  \
# 0  0.6  0.5  0.1  0.5  1.7   6.0  2016    Álex Abrines        0
# 1  1.1  1.1  1.0  1.8  2.4  11.3  2016    Steven Adams        0
# 2  2.0  0.4  0.1  0.7  1.2   2.9  2016  Semaj Christon        0
# 3  1.1  0.6  0.0  0.5  1.4   3.3  2016     Norris Cole        0
# 4  0.6  0.1  0.1  0.2  0.9   1.7  2016   Nick Collison        0
#
#                     Team Overall      win%       GS%
# 0  Oklahoma City Thunder   47-35  0.573171  0.088235
# 1  Oklahoma City Thunder   47-35  0.573171  1.000000
# 2  Oklahoma City Thunder   47-35  0.573171  0.015625
# 3  Oklahoma City Thunder   47-35  0.573171  0.000000
# 4  Oklahoma City Thunder   47-35  0.573171  0.000000

# %%
data = df.drop(columns=['Rk','Player','Pos','Tm','G','GS','name','year','allstar','Team','Overall'])
data_cols = data.columns
labels = df['allstar']

data_2019 = d2019.drop(columns=['Rk','Player','Pos','Tm','G','GS','name','year','Team','Overall'])

train_data, test_data, train_labels, test_labels = train_test_split(data, labels, test_size=0.2, random_state=1, stratify=labels)

# %% [markdown]
# ### KNN Classifier - Non-Normalized

# %%
max_f1=0
k_opt=0
f1_scores = []
for k in range(1,20):
    knn = KNeighborsClassifier(n_neighbors = k)
    knn.fit(train_data,train_labels)
    predicted_labels = knn.predict(test_data)
    f1 = metrics.f1_score(test_labels, predicted_labels)
    f1_scores.append(f1)
    if f1 > max_f1:
        max_f1 = f1
        k_opt = k

fig, ax = plt.subplots(figsize=(10,7))
plt.plot(range(1,20), f1_scores)
plt.title('K Neighbors Classifier')
plt.xlabel('k (n_neighbors)')
plt.ylabel('f1 score')
ax.annotate('k={}, f1={}'.format(k_opt,max_f1), (k_opt, f1_scores[k_opt]))
plt.show()

# %%
knn = KNeighborsClassifier(n_neighbors = k_opt)
knn.fit(train_data,train_labels)
predicted_labels = knn.predict(test_data)
predicted_2019 = knn.predict(data_2019)

print("K Neighbors Classifier (k={})\naccuracy_score={}\nprecision={}\nrecall={}\nf1_score={}\nconfusion matrix\n{}".format(
    k_opt,
    metrics.accuracy_score(test_labels, predicted_labels),
    metrics.precision_score(test_labels, predicted_labels),
    metrics.recall_score(test_labels, predicted_labels),
    metrics.f1_score(test_labels, predicted_labels),
    metrics.confusion_matrix(test_labels, predicted_labels)
))
# Out:
# K Neighbors Classifier (k=7)
# accuracy_score=0.9779411764705882
# precision=0.7857142857142857
# recall=0.7857142857142857
# f1_score=0.7857142857142857
# confusion matrix
# [[255   3]
#  [  3  11]]

# %%
knn_results = test_data.merge(df)
knn_results.rename({'allstar':'actual'}, axis=1, inplace=True)
knn_results['predicted'] = predicted_labels
knn_results.sort_values(by='actual', ascending=False, inplace=True)
knn_results[(knn_results['actual']==1) |  (knn_results['predicted']==1)][['name','year','actual','predicted']].reset_index(drop=True)
# Out:
#                  name  year  actual  predicted
# 0    D'Angelo Russell  2018       1          0
# 1          Al Horford  2017       1          0
# 2        Kevin Durant  2016       1          1
# 3      Damian Lillard  2018       1          1
# 4        Bradley Beal  2018       1          1
# 5   Russell Westbrook  2016       1          1
# 6      Nikola Vučević  2018       1          1
# 7        Kemba Walker  2017       1          1
# 8        LeBron James  2017       1          1
# 9       Blake Griffin  2018       1          1
# 10     Andre Drummond  2017       1          0
# 11       Jimmy Butler  2016       1          1
# 12     Gordon Hayward  2016       1          1
# 13       James Harden  2017       1          1
# 14     Damian Lillard  2016       0          1
# 15        CJ McCollum  2018       0          1
# 16       Devin Booker  2018       0          1

# %%
pred_2019 = data_2019.merge(d2019)
pred_2019['predicted'] = predicted_2019
pred_2019.sort_values(by='predicted', ascending=False, inplace=True)
pred_2019[pred_2019['predicted']==1][['name','predicted']].reset_index(drop=True)
# Out:
#                      name  predicted
# 0            Devin Booker          1
# 1            LeBron James          1
# 2             Luka Dončić          1
# 3       LaMarcus Aldridge          1
# 4           DeMar DeRozan          1
# 5        D'Angelo Russell          1
# 6             Zach LaVine          1
# 7           Anthony Davis          1
# 8           Pascal Siakam          1
# 9   Giannis Antetokounmpo          1
# 10           Kyrie Irving          1
# 11         Brandon Ingram          1
# 12            Joel Embiid          1
# 13           Bradley Beal          1
# 14     Karl-Anthony Towns          1
# 15         Damian Lillard          1
# 16           Kemba Walker          1
# 17            CJ McCollum          1
# 18          Kawhi Leonard          1
# 19            Buddy Hield          1
# 20           James Harden          1
# 21             Trae Young          1
# 22            Paul George          1
# 23      Russell Westbrook          1

# %% [markdown]
# ### Random Forest Classifier - Non-Normalized

# %%
max_f1=0
d_opt=0
f1_scores = []
for d in range(1,10):
    model = RandomForestClassifier(class_weight="balanced_subsample", max_depth=d, n_estimators=100, random_state=1)
    model.fit(train_data, train_labels)
    predicted_labels = model.predict(test_data)
    f1 = metrics.f1_score(test_labels, predicted_labels)
    f1_scores.append(f1)
    if f1 > max_f1:
        max_f1 = f1
        d_opt = d

fig1, ax1 = plt.subplots(figsize=(10,7))
plt.plot(range(1,10), f1_scores)
plt.title('Random Forest Classifier')
plt.xlabel('d (max_depth)')
plt.ylabel('f1 score')
ax1.annotate('d={}, f1={}'.format(d_opt,max_f1), (d_opt, f1_scores[d_opt]))
plt.show()

# %%
model = RandomForestClassifier(class_weight="balanced_subsample", max_depth=d_opt, n_estimators=100, random_state=1)
model.fit(train_data, train_labels)
predicted_labels = model.predict(test_data)
predicted_2019 = model.predict(data_2019)

print("Random Forest Classifier (d={})\naccuracy_score={}\nprecision={}\nrecall={}\nf1_score={}\nconfusion matrix\n{}".format(
    d_opt,
    metrics.accuracy_score(test_labels, predicted_labels),
    metrics.precision_score(test_labels, predicted_labels),
    metrics.recall_score(test_labels, predicted_labels),
    metrics.f1_score(test_labels, predicted_labels),
    metrics.confusion_matrix(test_labels, predicted_labels)
))
# Out:
# Random Forest Classifier (d=5)
# accuracy_score=0.9742647058823529
# precision=0.7333333333333333
# recall=0.7857142857142857
# f1_score=0.7586206896551724
# confusion matrix
# [[254   4]
#  [  3  11]]

# %%
rf_results = test_data.merge(df)
rf_results.rename({'allstar':'actual'}, axis=1, inplace=True)
rf_results['predicted'] = predicted_labels
rf_results.sort_values(by='actual', ascending=False, inplace=True)
rf_results[(rf_results['actual']==1) |  (rf_results['predicted']==1)][['name','year','actual','predicted']].reset_index(drop=True)
# Out:
#                  name  year  actual  predicted
# 0    D'Angelo Russell  2018       1          0
# 1          Al Horford  2017       1          0
# 2        Kevin Durant  2016       1          1
# 3      Damian Lillard  2018       1          1
# 4        Bradley Beal  2018       1          1
# 5   Russell Westbrook  2016       1          1
# 6      Nikola Vučević  2018       1          1
# 7        Kemba Walker  2017       1          1
# 8        LeBron James  2017       1          1
# 9       Blake Griffin  2018       1          1
# 10     Andre Drummond  2017       1          0
# 11       Jimmy Butler  2016       1          1
# 12     Gordon Hayward  2016       1          1
# 13       James Harden  2017       1          1
# 14           Rudy Gay  2016       0          1
# 15     Damian Lillard  2016       0          1
# 16        CJ McCollum  2018       0          1
# 17       Jimmy Butler  2017       0          1

# %%
pred_2019_rf = data_2019.merge(d2019)
pred_2019_rf['predicted'] = predicted_2019
pred_2019_rf.sort_values(by='predicted', ascending=False, inplace=True)
pred_2019_rf[pred_2019_rf['predicted']==1][['name','predicted']].reset_index(drop=True)
# Out:
#                      name  predicted
# 0            Devin Booker          1
# 1            Kemba Walker          1
# 2        D'Angelo Russell          1
# 3             Zach LaVine          1
# 4           Pascal Siakam          1
# 5            Nikola Jokić          1
# 6            Jrue Holiday          1
# 7          Brandon Ingram          1
# 8             CJ McCollum          1
# 9          Damian Lillard          1
# 10     Karl-Anthony Towns          1
# 11         Andrew Wiggins          1
# 12           Bradley Beal          1
# 13           Kyrie Irving          1
# 14           LeBron James          1
# 15       Donovan Mitchell          1
# 16          Anthony Davis          1
# 17          Julius Randle          1
# 18  Giannis Antetokounmpo          1
# 19      Russell Westbrook          1
# 20           James Harden          1
# 21          DeMar DeRozan          1
# 22          Kawhi Leonard          1

# %% [markdown]
# ### Logistic Regression Classifier - Non-Normalized

# %%
model = LogisticRegression()
model.fit(train_data, train_labels)
predicted_labels = model.predict(test_data)
probabilities = model.predict_proba(test_data)
predicted_2019 = model.predict(data_2019)
probabilities_2019 = model.predict_proba(data_2019)

print("Logistic Regression Classifier\naccuracy_score={}\nprecision={}\nrecall={}\nf1_score={}\nconfusion matrix\n{}".format(
    metrics.accuracy_score(test_labels, predicted_labels),
    metrics.precision_score(test_labels, predicted_labels),
    metrics.recall_score(test_labels, predicted_labels),
    metrics.f1_score(test_labels, predicted_labels),
    metrics.confusion_matrix(test_labels, predicted_labels)
))
# Out:
# Logistic Regression Classifier
# accuracy_score=0.9816176470588235
# precision=0.8461538461538461
# recall=0.7857142857142857
# f1_score=0.8148148148148148
# confusion matrix
# [[256   2]
#  [  3  11]]
# /Users/samfangman/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
results = test_data.merge(df)
results.rename({'allstar':'actual'}, axis=1, inplace=True)
results['predicted'] = predicted_labels
results['prob_as'] = probabilities[:,1]
results['prob_non'] = probabilities[:,0]
results.sort_values(by='prob_as', ascending=False, inplace=True)
results[(results['actual']==1) |  (results['predicted']==1)][['name','year','actual','prob_as','prob_non','predicted']].reset_index(drop=True)
# Out:
#                  name  year  actual   prob_as  prob_non  predicted
# 0   Russell Westbrook  2016       1  0.995734  0.004266          1
# 1        LeBron James  2017       1  0.993254  0.006746          1
# 2        Kevin Durant  2016       1  0.992426  0.007574          1
# 3        James Harden  2017       1  0.988307  0.011693          1
# 4      Damian Lillard  2016       0  0.898428  0.101572          1
# 5      Damian Lillard  2018       1  0.888360  0.111640          1
# 6      Nikola Vučević  2018       1  0.864539  0.135461          1
# 7    D'Angelo Russell  2018       1  0.717206  0.282794          1
# 8        Bradley Beal  2018       1  0.683720  0.316280          1
# 9        Kemba Walker  2017       1  0.584140  0.415860          1
# 10      Blake Griffin  2018       1  0.576723  0.423277          1
# 11       Devin Booker  2018       0  0.531596  0.468404          1
# 12       Jimmy Butler  2016       1  0.530256  0.469744          1
# 13     Gordon Hayward  2016       1  0.495944  0.504056          0
# 14         Al Horford  2017       1  0.096503  0.903497          0
# 15     Andre Drummond  2017       1  0.040859  0.959141          0

# %%
pred_2019 = data_2019.merge(d2019)
pred_2019['predicted'] = predicted_2019
pred_2019['prob_as'] = probabilities_2019[:,1]
pred_2019['prob_non'] = probabilities_2019[:,0]
pred_2019.sort_values(by='prob_as', ascending=False, inplace=True)
pred_2019[pred_2019['predicted']==1][['name','predicted', 'prob_as']].reset_index(drop=True)
# Out:
#                      name  predicted   prob_as
# 0   Giannis Antetokounmpo          1  0.998070
# 1             Luka Dončić          1  0.995616
# 2            LeBron James          1  0.992284
# 3            James Harden          1  0.991849
# 4          Damian Lillard          1  0.981210
# 5           Kawhi Leonard          1  0.967123
# 6              Trae Young          1  0.964140
# 7           Anthony Davis          1  0.952267
# 8            Kyrie Irving          1  0.950017
# 9      Karl-Anthony Towns          1  0.915227
# 10           Bradley Beal          1  0.854032
# 11       D'Angelo Russell          1  0.785229
# 12           Kemba Walker          1  0.736895
# 13         Brandon Ingram          1  0.695305
# 14            Joel Embiid          1  0.694347
# 15          Pascal Siakam          1  0.688798
# 16           Devin Booker          1  0.673502
# 17       Donovan Mitchell          1  0.643048
# 18        Khris Middleton          1  0.640183
# 19            Paul George          1  0.638931
# 20           Nikola Jokić          1  0.625363
# 21           Jayson Tatum          1  0.599140
# 22            Zach LaVine          1  0.569157
# 23      Russell Westbrook          1  0.564713

# %%
coefs_df = pd.DataFrame({'feature':data_cols,'weight':model.coef_[0]})
coefs_df['weight_abs'] = coefs_df.weight.abs()
coefs_df.sort_values(by='weight_abs', ascending=False, inplace=True)
coefs_df.reset_index(inplace=True, drop=True)
coefs_df
# Out:
#    feature    weight  weight_abs
# 0      FT% -1.224884    1.224884
# 1     eFG% -1.064178    1.064178
# 2      2P% -1.020103    1.020103
# 3      FG% -0.947554    0.947554
# 4     win%  0.920123    0.920123
# 5      TOV -0.900038    0.900038
# 6      3P% -0.885735    0.885735
# 7      BLK  0.735870    0.735870
# 8      GS%  0.687253    0.687253
# 9       PF -0.665775    0.665775
# 10     ORB -0.561846    0.561846
# 11     PTS  0.553891    0.553891
# 12     AST  0.553617    0.553617
# 13     DRB  0.454555    0.454555
# 14      FG  0.350691    0.350691
# 15     FTA -0.203700    0.203700
# 16      MP -0.180874    0.180874
# 17     FGA -0.158595    0.158595
# 18      3P  0.158244    0.158244
# 19     2PA -0.148269    0.148269
# 20      2P  0.118971    0.118971
# 21     STL  0.091781    0.091781
# 22     3PA -0.052423    0.052423
# 23     Age -0.046761    0.046761
# 24     TRB  0.035452    0.035452
# 25      FT  0.018097    0.018097

# %% [markdown]
# ### Normalize Dataset

# %%
names = list(df['name'])
allstars = list(df['allstar'])
years = list(df['year'])
names_2019 = list(d2019['name'])
scaled_data = scale(data, axis=0)
scaled_names = pd.DataFrame(scaled_data)
scaled_names.columns = data_cols
scaled_names['name'] = names
scaled_names['actual'] = allstars
scaled_names['year'] = years
scaled_data_2019 = scale(data_2019, axis=0)
scaled_names_2019 = pd.DataFrame(scaled_data_2019)
scaled_names_2019.columns = data_cols
scaled_names_2019['name'] = names_2019
train_data, test_data, train_labels, test_labels = train_test_split(scaled_data, labels, test_size=0.2, random_state=1, stratify=labels)
test_data_df = pd.DataFrame(test_data)
test_data_df.columns = data_cols

# scaled_names.head()

# %% [markdown]
# ### KNN Classifier - Normalized

# %%
max_f1=0
k_opt=0
f1_scores = []
for k in range(1,20):
    knn = KNeighborsClassifier(n_neighbors = k)
    knn.fit(train_data,train_labels)
    predicted_labels = knn.predict(test_data)
    f1 = metrics.f1_score(test_labels, predicted_labels)
    f1_scores.append(f1)
    if f1 > max_f1:
        max_f1 = f1
        k_opt = k

fig, ax = plt.subplots(figsize=(10,7))
plt.plot(range(1,20), f1_scores)
plt.title('K Neighbors Classifier')
plt.xlabel('k (n_neighbors)')
plt.ylabel('f1 score')
ax.annotate('k={}, f1={}'.format(k_opt,max_f1), (k_opt, f1_scores[k_opt]))
plt.show()

# %%
knn = KNeighborsClassifier(n_neighbors = k_opt)
knn.fit(train_data,train_labels)
predicted_labels = knn.predict(test_data)
predicted_2019 = knn.predict(scaled_data_2019)

print("K Neighbors Classifier (k={})\naccuracy_score={}\nprecision={}\nrecall={}\nf1_score={}\nconfusion matrix\n{}".format(
    k_opt,
    metrics.accuracy_score(test_labels, predicted_labels),
    metrics.precision_score(test_labels, predicted_labels),
    metrics.recall_score(test_labels, predicted_labels),
    metrics.f1_score(test_labels, predicted_labels),
    metrics.confusion_matrix(test_labels, predicted_labels)
))
# Out:
# K Neighbors Classifier (k=4)
# accuracy_score=0.9779411764705882
# precision=0.8333333333333334
# recall=0.7142857142857143
# f1_score=0.7692307692307692
# confusion matrix
# [[256   2]
#  [  4  10]]

# %%
knn_results = test_data_df.merge(scaled_names)
knn_results.rename({'allstar':'actual'}, axis=1, inplace=True)
knn_results['predicted'] = predicted_labels
knn_results.sort_values(by='actual', ascending=False, inplace=True)
knn_results[(knn_results['actual']==1) |  (knn_results['predicted']==1)][['name','year','actual','predicted']].reset_index(drop=True)
# Out:
#                  name  year  actual  predicted
# 0    D'Angelo Russell  2018       1          1
# 1          Al Horford  2017       1          0
# 2        Kevin Durant  2016       1          1
# 3      Damian Lillard  2018       1          1
# 4        Bradley Beal  2018       1          1
# 5   Russell Westbrook  2016       1          1
# 6      Nikola Vučević  2018       1          0
# 7        Kemba Walker  2017       1          1
# 8        LeBron James  2017       1          1
# 9       Blake Griffin  2018       1          1
# 10     Andre Drummond  2017       1          0
# 11       Jimmy Butler  2016       1          1
# 12     Gordon Hayward  2016       1          0
# 13       James Harden  2017       1          1
# 14     Damian Lillard  2016       0          1
# 15       Jimmy Butler  2017       0          1

# %%
pred_2019 = scaled_names_2019.copy()
pred_2019['predicted'] = predicted_2019
pred_2019.sort_values(by='predicted', ascending=False, inplace=True)
pred_2019[pred_2019['predicted']==1][['name','predicted']].reset_index(drop=True)
# Out:
#                      name  predicted
# 0            Devin Booker          1
# 1            Jimmy Butler          1
# 2             Zach LaVine          1
# 3           Pascal Siakam          1
# 4          Brandon Ingram          1
# 5          Damian Lillard          1
# 6            Bradley Beal          1
# 7             Joel Embiid          1
# 8            LeBron James          1
# 9            Kyrie Irving          1
# 10          Anthony Davis          1
# 11       Donovan Mitchell          1
# 12  Giannis Antetokounmpo          1
# 13      Russell Westbrook          1
# 14           James Harden          1
# 15             Trae Young          1
# 16            Paul George          1
# 17            Luka Dončić          1
# 18          Kawhi Leonard          1
# 19            Buddy Hield          1

# %% [markdown]
# ### Random Forest Classifier - Normalized

# %%
max_f1=0
d_opt=0
f1_scores = []
for d in range(1,10):
    model = RandomForestClassifier(class_weight="balanced_subsample", max_depth=d, n_estimators=100, random_state=1)
    model.fit(train_data, train_labels)
    predicted_labels = model.predict(test_data)
    f1 = metrics.f1_score(test_labels, predicted_labels)
    f1_scores.append(f1)
    if f1 > max_f1:
        max_f1 = f1
        d_opt = d

fig1, ax1 = plt.subplots(figsize=(10,7))
plt.plot(range(1,10), f1_scores)
plt.title('Random Forest Classifier')
plt.xlabel('d (max_depth)')
plt.ylabel('f1 score')
ax1.annotate('d={}, f1={}'.format(d_opt,max_f1), (d_opt, f1_scores[d_opt]))
plt.show()

# %%
model = RandomForestClassifier(class_weight="balanced_subsample", max_depth=d_opt, n_estimators=100, random_state=1)
model.fit(train_data, train_labels)
predicted_labels = model.predict(test_data)
predicted_2019 = model.predict(scaled_data_2019)

print("Random Forest Classifier (d={})\naccuracy_score={}\nprecision={}\nrecall={}\nf1_score={}\nconfusion matrix\n{}".format(
    d_opt,
    metrics.accuracy_score(test_labels, predicted_labels),
    metrics.precision_score(test_labels, predicted_labels),
    metrics.recall_score(test_labels, predicted_labels),
    metrics.f1_score(test_labels, predicted_labels),
    metrics.confusion_matrix(test_labels, predicted_labels)
))
# Out:
# Random Forest Classifier (d=5)
# accuracy_score=0.9742647058823529
# precision=0.7333333333333333
# recall=0.7857142857142857
# f1_score=0.7586206896551724
# confusion matrix
# [[254   4]
#  [  3  11]]

# %%
rf_results = test_data_df.merge(scaled_names)
rf_results.rename({'allstar':'actual'}, axis=1, inplace=True)
rf_results['predicted'] = predicted_labels
rf_results.sort_values(by='actual', ascending=False, inplace=True)
rf_results[(rf_results['actual']==1) |  (rf_results['predicted']==1)][['name','year','actual','predicted']].reset_index(drop=True)
# Out:
#                  name  year  actual  predicted
# 0    D'Angelo Russell  2018       1          0
# 1          Al Horford  2017       1          0
# 2        Kevin Durant  2016       1          1
# 3      Damian Lillard  2018       1          1
# 4        Bradley Beal  2018       1          1
# 5   Russell Westbrook  2016       1          1
# 6      Nikola Vučević  2018       1          1
# 7        Kemba Walker  2017       1          1
# 8        LeBron James  2017       1          1
# 9       Blake Griffin  2018       1          1
# 10     Andre Drummond  2017       1          0
# 11       Jimmy Butler  2016       1          1
# 12     Gordon Hayward  2016       1          1
# 13       James Harden  2017       1          1
# 14           Rudy Gay  2016       0          1
# 15     Damian Lillard  2016       0          1
# 16        CJ McCollum  2018       0          1
# 17       Jimmy Butler  2017       0          1

# %%
pred_2019_rf = scaled_names_2019.copy()
pred_2019_rf['predicted'] = predicted_2019
pred_2019_rf.sort_values(by='predicted', ascending=False, inplace=True)
pred_2019_rf[pred_2019_rf['predicted']==1][['name','predicted']].reset_index(drop=True)
# Out:
#                      name  predicted
# 0            Devin Booker          1
# 1            Bradley Beal          1
# 2        D'Angelo Russell          1
# 3           Pascal Siakam          1
# 4            Nikola Jokić          1
# 5          Brandon Ingram          1
# 6          Damian Lillard          1
# 7      Karl-Anthony Towns          1
# 8          Andrew Wiggins          1
# 9            LeBron James          1
# 10            Zach LaVine          1
# 11           Kyrie Irving          1
# 12          Anthony Davis          1
# 13       Donovan Mitchell          1
# 14          Julius Randle          1
# 15  Giannis Antetokounmpo          1
# 16      Russell Westbrook          1
# 17           James Harden          1
# 18          DeMar DeRozan          1
# 19          Kawhi Leonard          1

# %% [markdown]
# ### Logistic Regression Classifier - Normalized

# %%
model = LogisticRegression()
model.fit(train_data, train_labels)
predicted_labels = model.predict(test_data)
probabilities = model.predict_proba(test_data)
predicted_2019 = model.predict(scaled_data_2019)
probabilities_2019 = model.predict_proba(scaled_data_2019)

print("Logistic Regression Classifier\naccuracy_score={}\nprecision={}\nrecall={}\nf1_score={}\nconfusion matrix\n{}".format(
    metrics.accuracy_score(test_labels, predicted_labels),
    metrics.precision_score(test_labels, predicted_labels),
    metrics.recall_score(test_labels, predicted_labels),
    metrics.f1_score(test_labels, predicted_labels),
    metrics.confusion_matrix(test_labels, predicted_labels)
))
# Out:
# Logistic Regression Classifier
# accuracy_score=0.9742647058823529
# precision=0.8888888888888888
# recall=0.5714285714285714
# f1_score=0.6956521739130435
# confusion matrix
# [[257   1]
#  [  6   8]]
# /Users/samfangman/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
results = test_data_df.merge(scaled_names)
results.rename({'allstar':'actual'}, axis=1, inplace=True)
results['predicted'] = predicted_labels
results['prob_as'] = probabilities[:,1]
results['prob_non'] = probabilities[:,0]
results.sort_values(by='prob_as', ascending=False, inplace=True)
results[(results['actual']==1) |  (results['predicted']==1)][['name','year','actual','prob_as','prob_non','predicted']].reset_index(drop=True)
# Out:
#                  name  year  actual   prob_as  prob_non  predicted
# 0   Russell Westbrook  2016       1  0.995761  0.004239          1
# 1        James Harden  2017       1  0.994508  0.005492          1
# 2        LeBron James  2017       1  0.991287  0.008713          1
# 3        Kevin Durant  2016       1  0.988310  0.011690          1
# 4      Damian Lillard  2018       1  0.905799  0.094201          1
# 5      Damian Lillard  2016       0  0.801878  0.198122          1
# 6      Nikola Vučević  2018       1  0.722930  0.277070          1
# 7       Blake Griffin  2018       1  0.682366  0.317634          1
# 8        Bradley Beal  2018       1  0.504800  0.495200          1
# 9      Gordon Hayward  2016       1  0.445554  0.554446          0
# 10       Jimmy Butler  2016       1  0.439255  0.560745          0
# 11   D'Angelo Russell  2018       1  0.410984  0.589016          0
# 12       Kemba Walker  2017       1  0.358839  0.641161          0
# 13         Al Horford  2017       1  0.193442  0.806558          0
# 14     Andre Drummond  2017       1  0.103217  0.896783          0

# %%
pred_2019 = scaled_names_2019.copy()
pred_2019['predicted'] = predicted_2019
pred_2019['prob_as'] = probabilities_2019[:,1]
pred_2019['prob_non'] = probabilities_2019[:,0]
pred_2019.sort_values(by='prob_as', ascending=False, inplace=True)
pred_2019[pred_2019['predicted']==1][['name','predicted', 'prob_as']].reset_index(drop=True)
# Out:
#                      name  predicted   prob_as
# 0            James Harden          1  0.997380
# 1            LeBron James          1  0.993773
# 2   Giannis Antetokounmpo          1  0.990647
# 3          Damian Lillard          1  0.979382
# 4             Luka Dončić          1  0.979193
# 5           Kawhi Leonard          1  0.965643
# 6       Russell Westbrook          1  0.955615
# 7           Anthony Davis          1  0.954858
# 8            Kyrie Irving          1  0.951408
# 9              Trae Young          1  0.947506
# 10           Bradley Beal          1  0.939926
# 11     Karl-Anthony Towns          1  0.921463
# 12          Stephen Curry          1  0.825124
# 13       D'Angelo Russell          1  0.823586
# 14            Paul George          1  0.816538
# 15            Joel Embiid          1  0.810284
# 16          Pascal Siakam          1  0.807904
# 17           Kemba Walker          1  0.787700
# 18            Zach LaVine          1  0.779398
# 19         Nikola Vučević          1  0.749516
# 20          DeMar DeRozan          1  0.738389
# 21         Brandon Ingram          1  0.733374
# 22           Devin Booker          1  0.726071
# 23           Jrue Holiday          1  0.715199
# 24             Kyle Lowry          1  0.690223
# 25         Andrew Wiggins          1  0.688826
# 26             Kevin Love          1  0.687206
# 27            CJ McCollum          1  0.686846
# 28       Donovan Mitchell          1  0.654035
# 29           Jimmy Butler          1  0.644083
# 30      LaMarcus Aldridge          1  0.641835
# 31           Nikola Jokić          1  0.592185
# 32             Chris Paul          1  0.586247
# 33           Jayson Tatum          1  0.583042
# 34         Andre Drummond          1  0.557384
# 35          Tobias Harris          1  0.555397

# %%
coefs_df = pd.DataFrame({'feature':data_cols,'weight':model.coef_[0]})
coefs_df['weight_abs'] = coefs_df.weight.abs()
coefs_df.sort_values(by='weight_abs', ascending=False, inplace=True)
coefs_df.reset_index(inplace=True, drop=True)
coefs_df
# Out:
#    feature    weight  weight_abs
# 0     win%  0.816304    0.816304
# 1       FG  0.679001    0.679001
# 2       2P  0.594346    0.594346
# 3      PTS  0.593430    0.593430
# 4       MP -0.529626    0.529626
# 5      AST  0.528429    0.528429
# 6      Age  0.485402    0.485402
# 7      DRB  0.446690    0.446690
# 8       FT  0.365950    0.365950
# 9      3P% -0.347015    0.347015
# 10      3P  0.328777    0.328777
# 11     3PA  0.316175    0.316175
# 12     ORB -0.314419    0.314419
# 13     BLK  0.297004    0.297004
# 14     FT% -0.289105    0.289105
# 15     TOV -0.280162    0.280162
# 16     TRB  0.278545    0.278545
# 17      PF -0.253810    0.253810
# 18     FTA -0.191891    0.191891
# 19     FG% -0.123061    0.123061
# 20    eFG% -0.106104    0.106104
# 21     GS% -0.100162    0.100162
# 22     2P% -0.096096    0.096096
# 23     FGA  0.087045    0.087045
# 24     2PA -0.065439    0.065439
# 25     STL  0.048936    0.048936
